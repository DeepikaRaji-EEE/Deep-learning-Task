# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
import pandas as pd

data = pd.read_csv("/content/global_humanoid_robotics_intelligence_2026.csv")
data
# Out:
#         robot_uid                  robot_name  \
# 0   HRBT-9776433F               Optimus Gen 2
# 1   HRBT-AE204127            Atlas (Electric)
# 2   HRBT-6F112F40                   Figure 02
# 3   HRBT-4C9723C9                    Digit V4
# 4   HRBT-6175E4F1                Apollo Gen 1
# 5   HRBT-E960BF9D                     Phoenix
# 6   HRBT-C1BAD3CE                    Neo Beta
# 7   HRBT-20A0A6DE                  Unitree H1
# 8   HRBT-83A65CCE                  Unitree G1
# 9   HRBT-CEF6A47C                    Walker X
# 10  HRBT-8845FBB2                    Cyberone
# 11  HRBT-8C45A73E                    Tiangong
# 12  HRBT-9645E6F4                Fourier Gr-1
# 13  HRBT-53B09E03                   Aimbot S1
# 14  HRBT-54D7A7B7                       Kuavo
# 15  HRBT-D86D3239                 Astribot S1
# 16  HRBT-039BB1B1               Bd-1 Humanoid
# 17  HRBT-04FB2C0E             Asimo (Retired)
# 18  HRBT-500EB61E                      Hrp-5P
# ...

# %%
data.columns = data.columns.str.strip()

# %%
X = data[['robot_name', 'founded_year',	'company']].values

# %%
print(data[['founded_year', 'robot_name']].head())
# Out:
#    founded_year        robot_name
# 0          2021     Optimus Gen 2
# 1          1992  Atlas (Electric)
# 2          2022         Figure 02
# 3          2015          Digit V4
# 4          2016      Apollo Gen 1

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Create ANN model
model = Sequential()
model.add(Dense(8, input_dim=3, activation='relu'))
model.add(Dense(3, activation='softmax'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compile the ANN model
model.compile(
    loss='sparse_categorical_crossentropy',  # For integer class labels (0, 1, 2)
    optimizer='adam',
    metrics=['accuracy']
)

# %%
# Train model
model.fit(x, y, epochs=50)

# %%
# Take user input
sleep = float(input("Enter Sleep Hours: "))
stress = float(input("Enter Stress Level (1-10): "))
activity = float(input("Enter Physical Activity Level: "))

# %%
# Convert into numpy array
test = np.array([[sleep, stress, activity]])
pred = model.predict(test)
labels = ["Happy", "Stress", "Tired"]
print("Mood:", labels[np.argmax(pred)])
